# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def findNumbers(self, nums: List[int]) -> int:
        count=0
        for num in range(0, len(nums)):
            ans=str(nums[num])
            if len(ans)%2==0:
                count+=1
        return count
